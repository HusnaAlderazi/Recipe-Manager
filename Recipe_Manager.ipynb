# %%
import recipes_func

# %%
recipes_func.main()
# Out:
# Welcome to Recipe Manager!
# This app helps you build your own recipes.
#
# === Recipes Menu ===
# 1. List All Recipes
# 2. View A Random Recipes
# 3. Sort Recipes By Date Preparation
# 4. Sort Recipes By Rating
# 5. Search By Ingredients
# 6. Add New Recipe
# 7. Search by Category
# 8. Exit
# Select A Number From (1-8):  7
# Please enter a valid ategory: Breakfast', 'Lunch', 'Dinner','Dessert.
# Choose Category Option:  Lunch
# 1. Grilled Chicken Caesar Salad - 2 chicken breasts, 1 romaine lettuce, 1/2 cup Caesar dressing, 1/2 cup parmesan, 1 cup croutons, 1 lemon, 2 cloves garlic, salt and pepper
# 2. Lentil Soup - 2 cups red lentils, 1 onion (diced), 3 cloves garlic, 2 carrots (diced), 2 celery stalks, 1 can diced tomatoes, 6 cups vegetable broth, 1 tsp cumin, 1 tsp turmeric, salt and pepper, olive oil
# ...

# %%
import recipes_func_v2

# %%
recipes_func_v2.main()
# Out:
# Select A Number From The List Below:
#
#             0. Leave The Program
#             1. List All Recipes
#             2. View A Random Recipes
#             3. Sort Recipes By Date Preparation
#             4. Sort Recipes By Rating
#             5. Search By Ingredients
#             6. Add New Recipe
#             7. Scale Ingredients Quantity By Number Of Servings
#             8. Generate Shopping List
#
#  8
# Pancakes
# Chicken Salad
# Spaghetti Bolognese
# Chocolate Cake
# Omelette
# Grilled Fish
# Fruit Salad
